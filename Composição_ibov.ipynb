# %% [markdown]
# <a href="https://colab.research.google.com/github/Cassi686/Cassi686/blob/main/Composi%C3%A7%C3%A3o_ibov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import yfinance as yf

# %%
df = pd.read_csv('/content/IBOVDia_11-09-23.csv',encoding='latin-1', header = 1, sep=';')
df.head()
# Out:
#              Código        Ação           Tipo Qtde. Teórica  Part. (%)
# RRRP3  3R PETROLEUM  ON      NM    235.661.666         0,377        NaN
# ALSO3  ALIANSCSONAE  ON      NM    532.616.595         0,596        NaN
# ALPA4    ALPARGATAS  PN      N1    208.965.950         0,087        NaN
# ABEV3     AMBEV S/A          ON  4.394.245.879         2,980        NaN
# ARZZ3     AREZZO CO  ON      NM     62.305.891         0,208        NaN

# %%
df.index
# Out:
# Index(['RRRP3', 'ALSO3', 'ALPA4', 'ABEV3', 'ARZZ3', 'ASAI3', 'AZUL4', 'B3SA3',
#        'BBSE3', 'BBDC3', 'BBDC4', 'BRAP4', 'BBAS3', 'BRKM5', 'BRFS3', 'BPAC11',
#        'CRFB3', 'CCRO3', 'CMIG4', 'CIEL3', 'COGN3', 'CPLE6', 'CSAN3', 'CPFE3',
#        'CMIN3', 'CVCB3', 'CYRE3', 'DXCO3', 'ELET3', 'ELET6', 'EMBR3', 'ENGI11',
#        'ENEV3', 'EGIE3', 'EQTL3', 'EZTC3', 'FLRY3', 'GGBR4', 'GOAU4', 'GOLL4',
#        'NTCO3', 'SOMA3', 'HAPV3', 'HYPE3', 'IGTI11', 'IRBR3', 'ITSA4', 'ITUB4',
#        'JBSS3', 'KLBN11', 'RENT3', 'LWSA3', 'LREN3', 'MGLU3', 'MRFG3', 'BEEF3',
#        'MRVE3', 'MULT3', 'PCAR3', 'PETR3', 'PETR4', 'RECV3', 'PRIO3', 'PETZ3',
#        'RADL3', 'RAIZ4', 'RDOR3', 'RAIL3', 'SBSP3', 'SANB11', 'SMTO3', 'CSNA3',
#        'SLCE3', 'SUZB3', 'TAEE11', 'VIVT3', 'TIMS3', 'TOTS3', 'UGPA3', 'USIM5',
#        'VALE3', 'VAMO3', 'VIIA3', 'VBBR3', 'WEGE3', 'YDUQ3',
#        'Quantidade Teórica Total', 'Redutor'],
#       dtype='object')

# %%
df.index[0:-2]
# Out:
# Index(['RRRP3', 'ALSO3', 'ALPA4', 'ABEV3', 'ARZZ3', 'ASAI3', 'AZUL4', 'B3SA3',
#        'BBSE3', 'BBDC3', 'BBDC4', 'BRAP4', 'BBAS3', 'BRKM5', 'BRFS3', 'BPAC11',
#        'CRFB3', 'CCRO3', 'CMIG4', 'CIEL3', 'COGN3', 'CPLE6', 'CSAN3', 'CPFE3',
#        'CMIN3', 'CVCB3', 'CYRE3', 'DXCO3', 'ELET3', 'ELET6', 'EMBR3', 'ENGI11',
#        'ENEV3', 'EGIE3', 'EQTL3', 'EZTC3', 'FLRY3', 'GGBR4', 'GOAU4', 'GOLL4',
#        'NTCO3', 'SOMA3', 'HAPV3', 'HYPE3', 'IGTI11', 'IRBR3', 'ITSA4', 'ITUB4',
#        'JBSS3', 'KLBN11', 'RENT3', 'LWSA3', 'LREN3', 'MGLU3', 'MRFG3', 'BEEF3',
#        'MRVE3', 'MULT3', 'PCAR3', 'PETR3', 'PETR4', 'RECV3', 'PRIO3', 'PETZ3',
#        'RADL3', 'RAIZ4', 'RDOR3', 'RAIL3', 'SBSP3', 'SANB11', 'SMTO3', 'CSNA3',
#        'SLCE3', 'SUZB3', 'TAEE11', 'VIVT3', 'TIMS3', 'TOTS3', 'UGPA3', 'USIM5',
#        'VALE3', 'VAMO3', 'VIIA3', 'VBBR3', 'WEGE3', 'YDUQ3'],
#       dtype='object')

# %%
list(df.index[0:-2])
# Out:
# ['RRRP3',
#  'ALSO3',
#  'ALPA4',
#  'ABEV3',
#  'ARZZ3',
#  'ASAI3',
#  'AZUL4',
#  'B3SA3',
#  'BBSE3',
#  'BBDC3',
#  'BBDC4',
#  'BRAP4',
#  'BBAS3',
#  'BRKM5',
#  'BRFS3',
#  'BPAC11',
#  'CRFB3',
#  'CCRO3',
#  'CMIG4',
#  'CIEL3',
#  'COGN3',
#  'CPLE6',
#  'CSAN3',
#  'CPFE3',
#  'CMIN3',
#  'CVCB3',
#  'CYRE3',
#  'DXCO3',
#  'ELET3',
#  'ELET6',
#  'EMBR3',
#  'ENGI11',
#  'ENEV3',
#  'EGIE3',
#  'EQTL3',
#  'EZTC3',
#  'FLRY3',
#  'GGBR4',
#  'GOAU4',
#  'GOLL4',
#  'NTCO3',
#  'SOMA3',
#  'HAPV3',
#  'HYPE3',
#  'IGTI11',
#  'IRBR3',
#  'ITSA4',
#  'ITUB4',
#  'JBSS3',
#  'KLBN11',
#  'RENT3',
#  'LWSA3',
#  'LREN3',
#  'MGLU3',
#  'MRFG3',
#  'BEEF3',
#  'MRVE3',
#  'MULT3',
#  'PCAR3',
#  'PETR3',
#  'PETR4',
#  'RECV3',
#  'PRIO3',
#  'PETZ3',
#  'RADL3',
#  'RAIZ4',
#  'RDOR3',
#  'RAIL3',
#  'SBSP3',
#  'SANB11',
#  'SMTO3',
#  'CSNA3',
#  'SLCE3',
#  'SUZB3',
#  'TAEE11',
#  'VIVT3',
#  'TIMS3',
#  'TOTS3',
#  'UGPA3',
#  'USIM5',
#  'VALE3',
#  'VAMO3',
# ...

# %%
tickers = list(df.index[0:-2])

# %%
[acao + '.SA' for acao in tickers]
# Out:
# ['RRRP3.SA',
#  'ALSO3.SA',
#  'ALPA4.SA',
#  'ABEV3.SA',
#  'ARZZ3.SA',
#  'ASAI3.SA',
#  'AZUL4.SA',
#  'B3SA3.SA',
#  'BBSE3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BRAP4.SA',
#  'BBAS3.SA',
#  'BRKM5.SA',
#  'BRFS3.SA',
#  'BPAC11.SA',
#  'CRFB3.SA',
#  'CCRO3.SA',
#  'CMIG4.SA',
#  'CIEL3.SA',
#  'COGN3.SA',
#  'CPLE6.SA',
#  'CSAN3.SA',
#  'CPFE3.SA',
#  'CMIN3.SA',
#  'CVCB3.SA',
#  'CYRE3.SA',
#  'DXCO3.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'EMBR3.SA',
#  'ENGI11.SA',
#  'ENEV3.SA',
#  'EGIE3.SA',
#  'EQTL3.SA',
#  'EZTC3.SA',
#  'FLRY3.SA',
#  'GGBR4.SA',
#  'GOAU4.SA',
#  'GOLL4.SA',
#  'NTCO3.SA',
#  'SOMA3.SA',
#  'HAPV3.SA',
#  'HYPE3.SA',
#  'IGTI11.SA',
#  'IRBR3.SA',
#  'ITSA4.SA',
#  'ITUB4.SA',
#  'JBSS3.SA',
#  'KLBN11.SA',
#  'RENT3.SA',
#  'LWSA3.SA',
#  'LREN3.SA',
#  'MGLU3.SA',
#  'MRFG3.SA',
#  'BEEF3.SA',
#  'MRVE3.SA',
#  'MULT3.SA',
#  'PCAR3.SA',
#  'PETR3.SA',
#  'PETR4.SA',
#  'RECV3.SA',
#  'PRIO3.SA',
#  'PETZ3.SA',
#  'RADL3.SA',
#  'RAIZ4.SA',
# ...

# %%
tickers_novo = [acao + '.SA' for acao in tickers]

# %%
yf.download(tickers_novo, start = '2023-01-01')
# Out:
# [*********************100%%**********************]  86 of 86 completed
#            Adj Close                                                     \
#             ABEV3.SA ALPA4.SA   ALSO3.SA   ARZZ3.SA   ASAI3.SA AZUL4.SA
# Date
# 2023-01-02     14.19    14.33  15.826699  73.323433  18.912775    10.30
# 2023-01-03     14.17    13.40  15.146190  71.038254  18.534321    10.16
# 2023-01-04     14.25    13.49  15.292012  72.670517  19.002409    10.56
# 2023-01-05     14.29    13.86  15.787812  73.541061  18.902815    11.55
# 2023-01-06     14.32    13.87  16.244724  74.985374  18.962574    11.84
# ...              ...      ...        ...        ...        ...      ...
# 2023-09-01     13.87     8.83  22.990000  73.690002  11.860000    14.93
# 2023-09-04     13.86     8.94  22.959999  73.519997  12.250000    14.81
# 2023-09-05     14.01     8.95  22.850000  71.830002  12.770000    14.09
# 2023-09-06     13.98     8.77  22.540001  68.870003  12.500000    13.81
# ...

# %%
yf.download(tickers_novo, start = '2023-01-01')['Close']
# Out:
# [*********************100%%**********************]  86 of 86 completed
#             ABEV3.SA  ALPA4.SA   ALSO3.SA   ARZZ3.SA   ASAI3.SA  AZUL4.SA  \
# Date
# 2023-01-02     14.19     14.33  16.280001  74.120003  18.990000     10.30
# 2023-01-03     14.17     13.40  15.580000  71.809998  18.610001     10.16
# 2023-01-04     14.25     13.49  15.730000  73.459999  19.080000     10.56
# 2023-01-05     14.29     13.86  16.240000  74.339996  18.980000     11.55
# 2023-01-06     14.32     13.87  16.709999  75.800003  19.040001     11.84
# ...              ...       ...        ...        ...        ...       ...
# 2023-09-01     13.87      8.83  22.990000  73.690002  11.860000     14.93
# 2023-09-04     13.86      8.94  22.959999  73.519997  12.250000     14.81
# 2023-09-05     14.01      8.95  22.850000  71.830002  12.770000     14.09
# 2023-09-06     13.98      8.77  22.540001  68.870003  12.500000     13.81
# 2023-09-08     13.70      8.41  22.600000  67.500000  12.230000     13.67
#
# ...

# %%
ibov = yf.download(tickers_novo, start = '2023-01-01')['Close']
# Out:
# [*********************100%%**********************]  86 of 86 completed

# %%
ibov.plot();

# %%
ibov.to_csv('cotacoes_ibov.csv')
